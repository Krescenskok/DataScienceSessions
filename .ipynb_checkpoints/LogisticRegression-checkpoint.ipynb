# %% [markdown]
# ### Logistic Regression
# - Estimates the probability of an event occurring based on independent variables
# - Models a binary outcome (True/False, Yes/No)
#     - In this example, the outcome is either win or loss
# - Equation: $$ f(x) = {e^{b} \over (1+e^{-x})} $$

# %% [markdown]
# ### Prerequisite:
# - Download Anaconda (https://www.anaconda.com/download)
# - Install Github (https://gitforwindows.org/) (optional)
# - Set up Github account (optional)
# - Clone repository (git clone https://github.com/Krescenskok/DataScienceSessions.git) (optional)
# - Useful git commands (https://git-scm.com/docs)

# %% [markdown]
# ### Problem Statement and Hypothesis
# - Research Question: Can the business predict opportunity outcomes?
# - Alternate Hypothesis: Yes, we can predict opportunity outcomes
# - Null Hypothesis: No, we cannot predict opportunity outcomes

# %% [markdown]
# ### Why is it important to predict an opportunity with statistical significance?
# - Anticipate sales for CST and other leadership
# - Help influence a positive behavior

# %% [markdown]
# **Expected Outcome:** To have a model that can generalize trends in data using significant variables to predict a win or a loss.
# - Understand which opportunity variables are most significant
# - Figure out the accuracy of the model

# %% [markdown]
# **Data Collection Concerns:**
# - Dataset needs to have at least 10,000 records to prevent bias
# - At least 10 variables
# - At least 1 continuous and 1 categorical variable
# - Rights to use the data

# %% [markdown]
# **Data Variables:**
# - **Independent (x<sub>1</sub>-x<sub>n</sub>):** All other variables
# - **Dependent (Y):** Stage (Categorical variable - Outcomes are only win or loss)
#     - Logistic regressions are used to predict categorical outcomes

# %% [markdown]
# **Packages:**
# - **pandas:** Used for dataframes
# - **pyodbc:** Used to connect to SQL Server
# - **sklearn/stats model API:** Used for our logistic model
#     - Create train and test sets
#     - Recursive feature elimination
#     - Accuracy/precision/matrix scores
#     - Receiver operator characteristic
# - **seaborn/matplotlib:** Used for visualization

# %% [markdown]
# **Preprocessing Technique:**
# - Import packages and load data
# - Review the data
#     - head(), info()
#     - Handle missingness, outliers
# - Exploratory analysis
# - Variable selection

# %% [markdown]
# ### Import Packages and load data

# %%
#import packages
import pyodbc as db
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

#connect to DB
server = 'tcp:usaepwvds025.database.windows.net' 
database = 'SIMS' 
username = 'ciaserviceaccount' 
password = 'pipeline$330' 
cnxn = db.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

#load dataframe
sql = "select * from sims.logisticRegression"
df = pd.read_sql(sql,cnxn)

# %% [markdown]
# ### Review the data
# - Understand data types (Continuous vs Categorical)
# - Investigate missingness
# - Scale
# - Outliers

# %%
df.head()
# Out:
#   LegacySFInstance     LegacyAccountID  \
# 0              RxC  0013s00000uY8t8AAC
# 1              RxC  0013s00000xIwQOAA0
# 2              RxC  0013s00000zTk3cAAC
# 3              RxC  0013s000011ZefwAAC
# 4              RxC  0013s000011ZefwAAC
#
#                           LegacyAccountName  \
# 0  Coram Speciality Infusion Services, Inc.
# 1                                 Caris-MPI
# 2                                Pharma Pac
# 3        Biologics Financial Reconciliation
# 4        Biologics Financial Reconciliation
#
#                         CurrentCompanyGroup  CurrentCompanyID  \
# 0  Coram Speciality Infusion Services, Inc.               NaN
# 1                                 Caris-MPI               NaN
# 2                                Pharma Pac               NaN
# 3        Biologics Financial Reconciliation               NaN
# 4        Biologics Financial Reconciliation               NaN
#
#    CurrentCompanyMarketCap CurrentCompanyMarketCapCategory Top12CMMCompany  \
# 0                      NaN                            None            None
# 1                      NaN                            None            None
# 2                      NaN                            None            None
# 3                      NaN                            None            None
# 4                      NaN                            None            None
#
#   Top24CMMCompany       OpportunityID  \
# 0            None  0063s00000DSJH9AAP
# 1            None  0063s00000EAht5AAD
# 2            None  0063s00000DUuUEAA1
# 3            None  0063s00000EwxCLAAZ
# 4            None  0063s00000ExCSbAAN
#
#                                OpportunityName OpportunityType  \
# 0                       Coram/CVS Copay Finder             New
# 1                    Precision Medicine Survey             New
# 2                                   Pharma Pac             New
# 3  Biologics RARE - Launched for FY22 Tracking         Renewal
# 4   Biologics ONC - Launched for FY22 Tracking         Renewal
#
#    TotalOpportunityAmount          CreateDate   StartDate OpportunityOwner  \
# 0                     NaN 2019-08-06 19:15:55        None    Andrew Burman
# 1                200000.0 2017-05-31 15:15:14        None  Jennifer Frytak
# 2                173838.0 2020-04-09 15:52:13  2021-04-12    Ryan Grimmett
# 3              44986789.0 2021-02-04 14:55:41  2021-04-01      Laura Sieve
# 4              18086000.0 2021-04-27 15:01:37  2021-04-01      Laura Sieve
#
#      StageName         CloseReason                          CloseComments  \
# 0  Closed Lost              No Bid  Nothing materialized with the client.
# 1  Closed Lost  Client Funding Cut                                   None
# 2  Closed Lost           Cancelled                                   None
# 3   Closed Won                None                                   None
# 4   Closed Won                None                                   None
#
#   ImpactedFY
# 0    FY 2020
# 1    FY 2018
# 2    FY 2022
# 3    FY 2022
# 4    FY 2022

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27536 entries, 0 to 27535
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LegacySFInstance                 27536 non-null  object
#  1   LegacyAccountID                  27536 non-null  object
#  2   LegacyAccountName                27516 non-null  object
#  3   CurrentCompanyGroup              27516 non-null  object
#  4   CurrentCompanyID                 27459 non-null  float64
#  5   CurrentCompanyMarketCap          23084 non-null  float64
#  6   CurrentCompanyMarketCapCategory  27459 non-null  object
#  7   Top12CMMCompany                  10027 non-null  object
#  8   Top24CMMCompany                  4452 non-null   object
#  9   OpportunityID                    27536 non-null  object
#  10  OpportunityName                  27536 non-null  object
#  11  OpportunityType                  27536 non-null  object
#  12  TotalOpportunityAmount           26202 non-null  float64
#  13  CreateDate                       27536 non-null  datetime64[ns]
#  14  StartDate                        17081 non-null  object
#  15  OpportunityOwner                 27536 non-null  object
#  16  StageName                        27536 non-null  object
#  17  CloseReason                      12966 non-null  object
#  18  CloseComments                    3139 non-null   object
#  19  ImpactedFY                       27536 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(16)
# memory usage: 4.2+ MB

# %% [markdown]
# #### Drop ID Columns
# - Looking for patterns in the data. Since the ID columns are unique, this won't help us in predicting our win/loss opportunities

# %%
df = df.drop(columns=['LegacyAccountID', 'CurrentCompanyID', 'OpportunityID'])

# %% [markdown]
# We can't impute comments, so we will drop `CloseComments` from our dataset

# %%
df = df.drop(columns = 'CloseComments')

# %% [markdown]
# Since we have `CreateDate` that have no null values, we will use this column and drop `StartDate`

# %%
df = df.drop(columns = 'StartDate')

# %%
df.query('LegacyAccountName != LegacyAccountName')
# Out:
#    LegacySFInstance LegacyAccountName CurrentCompanyGroup  \
# 57              CMM              None                None
# 58              CMM              None                None
# 59              CMM              None                None
# 60              CMM              None                None
# 61              CMM              None                None
# 62              CMM              None                None
# 63              CMM              None                None
# 64              CMM              None                None
# 65              CMM              None                None
# 66              CMM              None                None
# 67              CMM              None                None
# 68              CMM              None                None
# 69              CMM              None                None
# 70              RHP              None                None
# 71              RHP              None                None
# 72              RHP              None                None
# 73              RHP              None                None
# 74              RHP              None                None
# 75              RHP              None                None
# 76              RHP              None                None
#
#     CurrentCompanyMarketCap CurrentCompanyMarketCapCategory Top12CMMCompany  \
# 57                      NaN                            None            None
# 58                      NaN                            None            None
# 59                      NaN                            None            None
# 60                      NaN                            None            None
# 61                      NaN                            None            None
# 62                      NaN                            None            None
# 63                      NaN                            None            None
# 64                      NaN                            None            None
# 65                      NaN                            None            None
# 66                      NaN                            None            None
# 67                      NaN                            None            None
# 68                      NaN                            None            None
# 69                      NaN                            None            None
# 70                      NaN                            None            None
# 71                      NaN                            None            None
# 72                      NaN                            None            None
# 73                      NaN                            None            None
# 74                      NaN                            None            None
# 75                      NaN                            None            None
# 76                      NaN                            None            None
#
#    Top24CMMCompany                                    OpportunityName  \
# 57            None  MDD Xadago (Safinamide) Prior Authorization Pl...
# 58            None  MDD Xadago (Safinamide) Prior Authorization Pl...
# 59            None                 MDD Xadago (Safinamide) HubExpress
# 60            None  MDD Xadago (Safinamide) Prior Authorization Pl...
# 61            None  testpharma Brand 1 Test Prior Authorization Pl...
# 62            None                              testpharma Brand4 IAN
# 63            None  testpharma Brand 1 Test Provider Medication Al...
# 64            None       testpharma BrandABC Prior Authorization Plus
# 65            None  testpharma BB TEST BRAND Prior Authorization Plus
# 66            None  testpharma BB TEST BRAND Prior Authorization Plus
# 67            None   testpharma Multibrand Clinical Alerts - Vaccines
# 68            None     testpharma Multibrand Prior Authorization Plus
# 69            None                testpharma BB TEST BRAND HubExpress
# 70            None             Kentucky Naloxone Copay *Legacy Copay*
# 71            None         Kentucky Board of Education - FY24 Renewal
# 72            None                      IGNORE: Test 2 5K New Bus Win
# 73            None                         IGNORE: Test 3 Renewal Win
# 74            None                Test KSP Email Alert New Pharma Biz
# 75            None                                         Test Opp 1
# 76            None                                         Test Opp 2
#
#    OpportunityType  TotalOpportunityAmount          CreateDate  \
# 57         Renewal               105250.00 2020-03-02 15:53:43
# 58         Renewal               105125.00 2021-05-10 17:42:46
# 59             New               148435.00 2021-04-19 14:40:04
# 60         Renewal                90575.00 2022-05-26 16:39:30
# 61         Renewal                50010.00 2019-01-03 21:30:43
# 62             New               350000.00 2020-10-30 13:44:15
# 63             New                   15.00 2021-02-02 16:27:41
# 64             New              1740232.24 2021-10-29 14:21:29
# 65             New               198042.50 2021-11-30 19:44:20
# 66             New               174042.50 2021-11-30 20:01:53
# 67             New                   11.97 2021-12-06 19:05:13
# 68             New              2641500.00 2021-12-06 20:41:49
# 69             New               300277.00 2023-06-27 14:52:46
# 70             New                     NaN 2022-08-05 20:02:14
# 71         Renewal                46980.00 2023-05-25 15:17:02
# 72             New                     NaN 2022-12-09 20:59:13
# 73         Renewal                     NaN 2022-12-09 21:00:49
# 74             New                64000.00 2021-11-19 15:55:31
# 75             New                     NaN 2019-03-19 16:43:46
# 76             New                     NaN 2019-03-19 17:10:38
#
#      OpportunityOwner    StageName                CloseReason ImpactedFY
# 57     Amanda Tegeder   Closed Won                       None    FY 2022
# 58        David Prevo   Closed Won                       None    FY 2023
# 59          Josh Lobs  Closed Lost                     Budget    FY 2022
# 60        David Prevo   Closed Won                       None    FY 2024
# 61     Julie Fielding  Closed Lost                       None    FY 2019
# 62     Julie Fielding  Closed Lost                     No Bid    FY 2021
# 63     Julie Fielding  Closed Lost                     No Bid    FY 2021
# 64       Jason Kemble  Closed Lost                     No Bid    FY 2022
# 65     Caroline Savoy  Closed Lost                     No Bid    FY 2022
# 66     Caroline Savoy  Closed Lost                     No Bid    FY 2022
# 67      Dorothy Brown  Closed Lost                     No Bid    FY 2022
# 68      Dorothy Brown  Closed Lost                     No Bid    FY 2022
# 69     Caroline Savoy  Closed Lost  Move to Other CMM Product    FY 2020
# 70       Scott Hughes   Closed Won                       None    FY 2023
# 71     Chris Anderson   Closed Won                       None    FY 2024
# 72  Doug Loudenslager  Closed Lost  General Market Conditions    FY 2023
# 73  Doug Loudenslager  Closed Lost  General Market Conditions    FY 2023
# 74         Keli Musil  Closed Lost                      Other    FY 2022
# 75       Scott Hughes  Closed Lost                     No Bid    FY 2020
# 76      Shawnta Welch  Closed Lost                No Decision    FY 2020

# %%
df.dropna(subset=['LegacyAccountName'], inplace=True)

# %% [markdown]
# Impute a value for missing market caps
# - Average value in the market cap category
# - Some companies don't have a market cap category, so we will first impute market cap categories

# %%
modeMarketCap = df['CurrentCompanyMarketCapCategory'].mode()
print(modeMarketCap)
df['CurrentCompanyMarketCapCategory'].fillna(df['CurrentCompanyMarketCapCategory'].mode()[0], inplace=True)
# Out:
# 0    Large
# Name: CurrentCompanyMarketCapCategory, dtype: object

# %%
meanMarketCap = df.groupby('CurrentCompanyMarketCapCategory')['CurrentCompanyMarketCap'].mean().reset_index()
print(meanMarketCap)
totalMeanMarketCap = df['CurrentCompanyMarketCap'].mean()
print(totalMeanMarketCap)
# Out:
#   CurrentCompanyMarketCapCategory  CurrentCompanyMarketCap
# 0                           Large             8.922738e+10
# 1                          Medium             5.178806e+09
# 2                            Mega             3.617039e+11
# 3                           Micro             8.615721e+07
# 4                   Not Available                      NaN
# 5                         Private                      NaN
# 6                           Small             1.121986e+09
# 133181497975.68924

# %%
df['CurrentCompanyMarketCap'] = df['CurrentCompanyMarketCap'].fillna(df.groupby('CurrentCompanyMarketCapCategory')['CurrentCompanyMarketCap'].transform('mean'))

# %%
df['CurrentCompanyMarketCap'].fillna(totalMeanMarketCap, inplace = True)

# %%
df['Top12CMMCompany'].fillna('False', inplace = True)
df['Top24CMMCompany'].fillna('False', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27516 entries, 0 to 27535
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LegacySFInstance                 27516 non-null  object
#  1   LegacyAccountName                27516 non-null  object
#  2   CurrentCompanyGroup              27516 non-null  object
#  3   CurrentCompanyMarketCap          27516 non-null  float64
#  4   CurrentCompanyMarketCapCategory  27516 non-null  object
#  5   Top12CMMCompany                  27516 non-null  object
#  6   Top24CMMCompany                  27516 non-null  object
#  7   OpportunityName                  27516 non-null  object
#  8   OpportunityType                  27516 non-null  object
#  9   TotalOpportunityAmount           26187 non-null  float64
#  10  CreateDate                       27516 non-null  datetime64[ns]
#  11  OpportunityOwner                 27516 non-null  object
#  12  StageName                        27516 non-null  object
#  13  CloseReason                      12952 non-null  object
#  14  ImpactedFY                       27516 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(12)
# memory usage: 3.4+ MB

# %%
avgTotalOppAmt = df['TotalOpportunityAmount'].mean()
print(avgTotalOppAmt)
df['TotalOpportunityAmount'].fillna(avgTotalOppAmt, inplace = True)
# Out:
# 748132.8779913697

# %%
CloseReasonMode = df['CloseReason'].mode()
print(CloseReasonMode)

df.loc[(df['CloseReason'].isna()) & (df['StageName'] == "Closed Lost"), 'CloseReason'] = "CloseReasonMode"

df.loc[(df['CloseReason'].isna()) & (df['StageName'] == "Closed Won"), 'CloseReason'] = "Won"
# Out:
# 0    No Bid
# Name: CloseReason, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27516 entries, 0 to 27535
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   LegacySFInstance                 27516 non-null  object
#  1   LegacyAccountName                27516 non-null  object
#  2   CurrentCompanyGroup              27516 non-null  object
#  3   CurrentCompanyMarketCap          27516 non-null  float64
#  4   CurrentCompanyMarketCapCategory  27516 non-null  object
#  5   Top12CMMCompany                  27516 non-null  object
#  6   Top24CMMCompany                  27516 non-null  object
#  7   OpportunityName                  27516 non-null  object
#  8   OpportunityType                  27516 non-null  object
#  9   TotalOpportunityAmount           27516 non-null  float64
#  10  CreateDate                       27516 non-null  datetime64[ns]
#  11  OpportunityOwner                 27516 non-null  object
#  12  StageName                        27516 non-null  object
#  13  CloseReason                      27516 non-null  object
#  14  ImpactedFY                       27516 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(12)
# memory usage: 3.4+ MB

# %%
df['CreateDateMonth'] = df['CreateDate'].dt.month

# %%
display(df)
# Out:
#       LegacySFInstance                         LegacyAccountName  \
# 0                  RxC  Coram Speciality Infusion Services, Inc.
# 1                  RxC                                 Caris-MPI
# 2                  RxC                                Pharma Pac
# 3                  RxC        Biologics Financial Reconciliation
# 4                  RxC        Biologics Financial Reconciliation
# ...                ...                                       ...
# 27531              RHP                     Biocon Biologics Inc.
# 27532              RHP                     Biocon Biologics Inc.
# 27533              RHP                     Biocon Biologics Inc.
# 27534              RHP                     Biocon Biologics Inc.
# 27535              RHP                           Sequel Med Tech
#
#                             CurrentCompanyGroup  CurrentCompanyMarketCap  \
# 0      Coram Speciality Infusion Services, Inc.             8.922738e+10
# 1                                     Caris-MPI             8.922738e+10
# 2                                    Pharma Pac             8.922738e+10
# 3            Biologics Financial Reconciliation             8.922738e+10
# 4            Biologics Financial Reconciliation             8.922738e+10
# ...                                         ...                      ...
# 27531                     Biocon Biologics Inc.             1.331815e+11
# 27532                     Biocon Biologics Inc.             1.331815e+11
# 27533                     Biocon Biologics Inc.             1.331815e+11
# 27534                     Biocon Biologics Inc.             1.331815e+11
# 27535                           Sequel Med Tech             1.331815e+11
#
#       CurrentCompanyMarketCapCategory Top12CMMCompany Top24CMMCompany  \
# 0                               Large           False           False
# 1                               Large           False           False
# 2                               Large           False           False
# 3                               Large           False           False
# 4                               Large           False           False
# ...                               ...             ...             ...
# 27531                   Not Available           False           False
# 27532                   Not Available           False           False
# 27533                   Not Available           False           False
# 27534                   Not Available           False           False
# 27535                   Not Available           False           False
#
#                                          OpportunityName OpportunityType  \
# 0                                 Coram/CVS Copay Finder             New
# 1                              Precision Medicine Survey             New
# 2                                             Pharma Pac             New
# 3            Biologics RARE - Launched for FY22 Tracking         Renewal
# 4             Biologics ONC - Launched for FY22 Tracking         Renewal
# ...                                                  ...             ...
# 27531                            Biocon Biologics_TS SOW             New
# 27532   Biocon Biologics_State Insulin Prog (MN, CO, ME)             New
# 27533    Biocon Biologics_LS, TS & State Insulin Imp SOW             New
# 27534  Biocon Biologics_State Insulin Prog (MN, CO, M...             New
# 27535                  Sequel MedTech_MSA + eV & DC SOWs             New
#
#        TotalOpportunityAmount          CreateDate OpportunityOwner  \
# 0                7.481329e+05 2019-08-06 19:15:55    Andrew Burman
# 1                2.000000e+05 2017-05-31 15:15:14  Jennifer Frytak
# 2                1.738380e+05 2020-04-09 15:52:13    Ryan Grimmett
# 3                4.498679e+07 2021-02-04 14:55:41      Laura Sieve
# 4                1.808600e+07 2021-04-27 15:01:37      Laura Sieve
# ...                       ...                 ...              ...
# 27531            6.298000e+04 2023-06-14 21:23:02     Laura Redman
# 27532            1.175200e+05 2023-06-29 23:19:29     Laura Redman
# 27533            0.000000e+00 2023-06-29 23:25:26     Laura Redman
# 27534            0.000000e+00 2024-01-15 17:36:03     Laura Redman
# 27535            7.481329e+05 2023-11-04 14:34:46     Laura Redman
#
#          StageName         CloseReason ImpactedFY  CreateDateMonth
# 0      Closed Lost              No Bid    FY 2020                8
# 1      Closed Lost  Client Funding Cut    FY 2018                5
# 2      Closed Lost           Cancelled    FY 2022                4
# 3       Closed Won                 Won    FY 2022                2
# 4       Closed Won                 Won    FY 2022                4
# ...            ...                 ...        ...              ...
# 27531   Closed Won                 Won    FY 2024                6
# 27532   Closed Won                 Won    FY 2024                6
# 27533   Closed Won                 Won    FY 2024                6
# 27534  Closed Lost              No Bid    FY 2024                1
# 27535   Closed Won                 Won    FY 2024               11
#
# [27516 rows x 16 columns]

# %% [markdown]
# ## Outliers
# - Outliers can skew the results of data analysis and impact model performance
# - Handling Outliers:
#     - Remove
#     - Impute
#     - Scale/Standardize

# %%
df.describe()
# Out:
#        CurrentCompanyMarketCap  TotalOpportunityAmount  \
# count             2.751600e+04            2.751600e+04
# mean              1.330904e+11            7.481329e+05
# min               6.493000e+01           -2.800000e+06
# 25%               1.434807e+10            5.460000e+03
# 50%               1.174317e+11            8.000000e+04
# 75%               1.576153e+11            3.203258e+05
# max               6.998863e+11            1.188350e+09
# std               1.496968e+11            1.265610e+07
#
#                           CreateDate  CreateDateMonth
# count                          27516     27516.000000
# mean   2018-01-10 03:30:22.928114688         6.538305
# min              2008-03-17 18:16:52         1.000000
# 25%    2015-06-19 23:24:36.750000128         4.000000
# 50%              2018-09-17 22:26:58         7.000000
# 75%       2021-03-03 14:36:56.500000         9.000000
# max              2024-02-19 20:48:25        12.000000
# std                              NaN         3.276881

# %% [markdown]
# Above, we see that `CreateDateMonth` is a numeric value when we want it to be a categorical value. So, we will convert it to an object type

# %%
df['CreateDateMonth'] = df['CreateDateMonth'].astype('object')

# %% [markdown]
# Customizing percentages allows us to view more about the data and decide whether our thoughts about outliers are accurate

# %%
## Customize percentiles
df.describe(percentiles=[.01, .05, .1, .25, .5, .75, .90, .95, .99])
# Out:
#        CurrentCompanyMarketCap  TotalOpportunityAmount  \
# count             2.751600e+04            2.751600e+04
# mean              1.330904e+11            7.481329e+05
# min               6.493000e+01           -2.800000e+06
# 1%                9.376078e+05            0.000000e+00
# 5%                1.477488e+08            0.000000e+00
# 10%               1.164934e+09            0.000000e+00
# 25%               1.434807e+10            5.460000e+03
# 50%               1.174317e+11            8.000000e+04
# 75%               1.576153e+11            3.203258e+05
# 90%               3.055616e+11            8.023059e+05
# 95%               3.799889e+11            1.957800e+06
# 99%               6.998863e+11            8.972833e+06
# max               6.998863e+11            1.188350e+09
# std               1.496968e+11            1.265610e+07
#
#                           CreateDate
# count                          27516
# mean   2018-01-10 03:30:22.928114688
# min              2008-03-17 18:16:52
# 1%        2008-05-19 20:03:54.200000
# 5%     2010-03-10 04:14:57.249999872
# 10%       2011-12-22 15:14:37.500000
# 25%    2015-06-19 23:24:36.750000128
# 50%              2018-09-17 22:26:58
# 75%       2021-03-03 14:36:56.500000
# 90%              2022-09-23 05:51:18
# 95%       2023-04-13 15:16:55.500000
# 99%    2023-11-07 14:13:14.649999872
# max              2024-02-19 20:48:25
# std                              NaN

# %%
import seaborn as sb
import statsmodels.api as sm

# %%
sb.boxplot(x='CurrentCompanyMarketCap',data=df) 
#Decision: Use min max scalar to scale the data to remove the impactive outliers
# Out:
# <Axes: xlabel='CurrentCompanyMarketCap'>

# %% [markdown]
# ## Exploratory Data Analysis
# - Data Visualization with `StageName`

# %%
df['StageName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='StageName'>

# %%
df['StageName'].value_counts()
# Out:
# StageName
# Closed Won     15381
# Closed Lost    12135
# Name: count, dtype: int64

# %%
df['StageName'] = df['StageName'].map({'Closed Won': 1, 'Closed Lost': 0})
winRate = (sum(df['StageName'])/len(df['StageName'].index))*100
print(winRate)
# Out:
# 55.898386393371126

# %%
pd.crosstab(df['ImpactedFY'],df['StageName']).plot(kind='line', title = 'Stage Name vs Impacted Fiscal Year')
# Out:
# <Axes: title={'center': 'Stage Name vs Impacted Fiscal Year'}, xlabel='ImpactedFY'>

# %%
pd.crosstab(df['CreateDateMonth'],df['StageName']).plot(kind='line', title = 'Stage Name vs Create Date Month')
# Out:
# <Axes: title={'center': 'Stage Name vs Create Date Month'}, xlabel='CreateDateMonth'>

# %% [markdown]
# - set_index: Allows one or more column values to become the row index. Here, we are using the 'CreateDate' as the new index so we can create a graph against that value
# - resample: Typically used for timeseries analysis. It generates a unique sampling distribution on the basis of actual data

# %%
df.head()
# Out:
#   LegacySFInstance                         LegacyAccountName  \
# 0              RxC  Coram Speciality Infusion Services, Inc.
# 1              RxC                                 Caris-MPI
# 2              RxC                                Pharma Pac
# 3              RxC        Biologics Financial Reconciliation
# 4              RxC        Biologics Financial Reconciliation
#
#                         CurrentCompanyGroup  CurrentCompanyMarketCap  \
# 0  Coram Speciality Infusion Services, Inc.             8.922738e+10
# 1                                 Caris-MPI             8.922738e+10
# 2                                Pharma Pac             8.922738e+10
# 3        Biologics Financial Reconciliation             8.922738e+10
# 4        Biologics Financial Reconciliation             8.922738e+10
#
#   CurrentCompanyMarketCapCategory Top12CMMCompany Top24CMMCompany  \
# 0                           Large           False           False
# 1                           Large           False           False
# 2                           Large           False           False
# 3                           Large           False           False
# 4                           Large           False           False
#
#                                OpportunityName OpportunityType  \
# 0                       Coram/CVS Copay Finder             New
# 1                    Precision Medicine Survey             New
# 2                                   Pharma Pac             New
# 3  Biologics RARE - Launched for FY22 Tracking         Renewal
# 4   Biologics ONC - Launched for FY22 Tracking         Renewal
#
#    TotalOpportunityAmount          CreateDate OpportunityOwner  StageName  \
# 0            7.481329e+05 2019-08-06 19:15:55    Andrew Burman          0
# 1            2.000000e+05 2017-05-31 15:15:14  Jennifer Frytak          0
# 2            1.738380e+05 2020-04-09 15:52:13    Ryan Grimmett          0
# 3            4.498679e+07 2021-02-04 14:55:41      Laura Sieve          1
# 4            1.808600e+07 2021-04-27 15:01:37      Laura Sieve          1
#
#           CloseReason ImpactedFY CreateDateMonth
# 0              No Bid    FY 2020               8
# 1  Client Funding Cut    FY 2018               5
# 2           Cancelled    FY 2022               4
# 3                 Won    FY 2022               2
# 4                 Won    FY 2022               4

# %%
df.set_index('CreateDate', inplace = True)
df.resample('1M').count()['StageName'].plot(title = 'Total Wins by Create Date')
# Out:
# <Axes: title={'center': 'Total Wins by Create Date'}, xlabel='CreateDate'>

# %%
#compare wins over LegacySFInstance
pd.crosstab(df['LegacySFInstance'],df['StageName']).plot(kind="bar", stacked=True, title = "Stage Name by Legacy SF Instance")
# Out:
# <Axes: title={'center': 'Stage Name by Legacy SF Instance'}, xlabel='LegacySFInstance'>

# %%
#compare wins by CurrentCompanyMarketCapCategory
pd.crosstab(df['CurrentCompanyMarketCapCategory'],df['StageName']).plot(kind="bar", stacked=True, title="Stage Name by Market Cap Category")
# Out:
# <Axes: title={'center': 'Stage Name by Market Cap Category'}, xlabel='CurrentCompanyMarketCapCategory'>

# %%
df.reset_index('CreateDate', inplace= True)

# %%
df.head()
# Out:
#            CreateDate LegacySFInstance  \
# 0 2019-08-06 19:15:55              RxC
# 1 2017-05-31 15:15:14              RxC
# 2 2020-04-09 15:52:13              RxC
# 3 2021-02-04 14:55:41              RxC
# 4 2021-04-27 15:01:37              RxC
#
#                           LegacyAccountName  \
# 0  Coram Speciality Infusion Services, Inc.
# 1                                 Caris-MPI
# 2                                Pharma Pac
# 3        Biologics Financial Reconciliation
# 4        Biologics Financial Reconciliation
#
#                         CurrentCompanyGroup  CurrentCompanyMarketCap  \
# 0  Coram Speciality Infusion Services, Inc.             8.922738e+10
# 1                                 Caris-MPI             8.922738e+10
# 2                                Pharma Pac             8.922738e+10
# 3        Biologics Financial Reconciliation             8.922738e+10
# 4        Biologics Financial Reconciliation             8.922738e+10
#
#   CurrentCompanyMarketCapCategory Top12CMMCompany Top24CMMCompany  \
# 0                           Large           False           False
# 1                           Large           False           False
# 2                           Large           False           False
# 3                           Large           False           False
# 4                           Large           False           False
#
#                                OpportunityName OpportunityType  \
# 0                       Coram/CVS Copay Finder             New
# 1                    Precision Medicine Survey             New
# 2                                   Pharma Pac             New
# 3  Biologics RARE - Launched for FY22 Tracking         Renewal
# 4   Biologics ONC - Launched for FY22 Tracking         Renewal
#
#    TotalOpportunityAmount OpportunityOwner  StageName         CloseReason  \
# 0            7.481329e+05    Andrew Burman          0              No Bid
# 1            2.000000e+05  Jennifer Frytak          0  Client Funding Cut
# 2            1.738380e+05    Ryan Grimmett          0           Cancelled
# 3            4.498679e+07      Laura Sieve          1                 Won
# 4            1.808600e+07      Laura Sieve          1                 Won
#
#   ImpactedFY CreateDateMonth
# 0    FY 2020               8
# 1    FY 2018               5
# 2    FY 2022               4
# 3    FY 2022               2
# 4    FY 2022               4

# %% [markdown]
# ## Encoding
# - Model cannot interpret strings, so we need to encode all the variables as numbers
# - Drop columns that have too many categories
# - Dummy variables
# - Curse of dimensionality

# %%
df.describe(include='object')
# Out:
#        LegacySFInstance  LegacyAccountName   CurrentCompanyGroup  \
# count             27516              27516                 27516
# unique                3               1628                   919
# top                 RxC  Merck & Co., Inc.  Bristol Myers Squibb
# freq              15084                845                  1487
#
#        CurrentCompanyMarketCapCategory Top12CMMCompany Top24CMMCompany  \
# count                            27516           27516           27516
# unique                               7               2               2
# top                              Large           False           False
# freq                             11751           17489           23064
#
#                           OpportunityName OpportunityType OpportunityOwner  \
# count                               27516           27516            27516
# unique                              25836               3              249
# top     2016 Mid-America Cancer Symposium             New       Admin User
# freq                                   36           19521             2532
#
#        CloseReason ImpactedFY  CreateDateMonth
# count        27516      27516            27516
# unique          76         23               12
# top            Won    FY 2023                9
# freq         13366       2838             3088

# %%
df = df.drop(columns=['LegacyAccountName', 'CurrentCompanyGroup', 'OpportunityName', 'OpportunityOwner', 'CloseReason', 'CreateDate'])

# %%
#'drop_first' argument is set to true to reduce redundancy and reduce the correlations created with the dummy variables
df = pd.get_dummies(df, columns=["LegacySFInstance", "CurrentCompanyMarketCapCategory", "Top12CMMCompany", "Top24CMMCompany", "OpportunityType","ImpactedFY", "CreateDateMonth"], prefix=["LegacySFInstance", "CurrentCompanyMarketCapCategory", "Top12CMMCompany", "Top24CMMCompany", "OpportunityType","ImpactedFY", "CreateDateMonth"], drop_first = True)

# %%
df.head()
# Out:
#    CurrentCompanyMarketCap  TotalOpportunityAmount  StageName  \
# 0             8.922738e+10            7.481329e+05          0
# 1             8.922738e+10            2.000000e+05          0
# 2             8.922738e+10            1.738380e+05          0
# 3             8.922738e+10            4.498679e+07          1
# 4             8.922738e+10            1.808600e+07          1
#
#    LegacySFInstance_RHP  LegacySFInstance_RxC  \
# 0                 False                  True
# 1                 False                  True
# 2                 False                  True
# 3                 False                  True
# 4                 False                  True
#
#    CurrentCompanyMarketCapCategory_Medium  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    CurrentCompanyMarketCapCategory_Mega  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    CurrentCompanyMarketCapCategory_Micro  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    CurrentCompanyMarketCapCategory_Not Available  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    CurrentCompanyMarketCapCategory_Private  ...  CreateDateMonth_3  \
# 0                                    False  ...              False
# 1                                    False  ...              False
# 2                                    False  ...              False
# 3                                    False  ...              False
# 4                                    False  ...              False
#
#    CreateDateMonth_4  CreateDateMonth_5  CreateDateMonth_6  CreateDateMonth_7  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2               True              False              False              False
# 3              False              False              False              False
# 4               True              False              False              False
#
#    CreateDateMonth_8  CreateDateMonth_9  CreateDateMonth_10  \
# 0               True              False               False
# 1              False              False               False
# 2              False              False               False
# 3              False              False               False
# 4              False              False               False
#
#    CreateDateMonth_11  CreateDateMonth_12
# 0               False               False
# 1               False               False
# 2               False               False
# 3               False               False
# 4               False               False
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27516 entries, 0 to 27515
# Data columns (total 48 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   CurrentCompanyMarketCap                        27516 non-null  float64
#  1   TotalOpportunityAmount                         27516 non-null  float64
#  2   StageName                                      27516 non-null  int64
#  3   LegacySFInstance_RHP                           27516 non-null  bool
#  4   LegacySFInstance_RxC                           27516 non-null  bool
#  5   CurrentCompanyMarketCapCategory_Medium         27516 non-null  bool
#  6   CurrentCompanyMarketCapCategory_Mega           27516 non-null  bool
#  7   CurrentCompanyMarketCapCategory_Micro          27516 non-null  bool
#  8   CurrentCompanyMarketCapCategory_Not Available  27516 non-null  bool
#  9   CurrentCompanyMarketCapCategory_Private        27516 non-null  bool
#  10  CurrentCompanyMarketCapCategory_Small          27516 non-null  bool
#  11  Top12CMMCompany_YES                            27516 non-null  bool
#  12  Top24CMMCompany_YES                            27516 non-null  bool
#  13  OpportunityType_Renewal                        27516 non-null  bool
#  14  OpportunityType_Termination                    27516 non-null  bool
#  15  ImpactedFY_FY 2005                             27516 non-null  bool
#  16  ImpactedFY_FY 2007                             27516 non-null  bool
#  17  ImpactedFY_FY 2008                             27516 non-null  bool
#  18  ImpactedFY_FY 2009                             27516 non-null  bool
#  19  ImpactedFY_FY 2010                             27516 non-null  bool
#  20  ImpactedFY_FY 2011                             27516 non-null  bool
#  21  ImpactedFY_FY 2012                             27516 non-null  bool
#  22  ImpactedFY_FY 2013                             27516 non-null  bool
#  23  ImpactedFY_FY 2014                             27516 non-null  bool
#  24  ImpactedFY_FY 2015                             27516 non-null  bool
#  25  ImpactedFY_FY 2016                             27516 non-null  bool
#  26  ImpactedFY_FY 2017                             27516 non-null  bool
#  27  ImpactedFY_FY 2018                             27516 non-null  bool
#  28  ImpactedFY_FY 2019                             27516 non-null  bool
#  29  ImpactedFY_FY 2020                             27516 non-null  bool
#  30  ImpactedFY_FY 2021                             27516 non-null  bool
#  31  ImpactedFY_FY 2022                             27516 non-null  bool
#  32  ImpactedFY_FY 2023                             27516 non-null  bool
#  33  ImpactedFY_FY 2024                             27516 non-null  bool
#  34  ImpactedFY_FY 2025                             27516 non-null  bool
#  35  ImpactedFY_FY 2026                             27516 non-null  bool
#  36  ImpactedFY_FY 2027                             27516 non-null  bool
#  37  CreateDateMonth_2                              27516 non-null  bool
#  38  CreateDateMonth_3                              27516 non-null  bool
#  39  CreateDateMonth_4                              27516 non-null  bool
#  40  CreateDateMonth_5                              27516 non-null  bool
#  41  CreateDateMonth_6                              27516 non-null  bool
#  42  CreateDateMonth_7                              27516 non-null  bool
#  43  CreateDateMonth_8                              27516 non-null  bool
#  44  CreateDateMonth_9                              27516 non-null  bool
#  45  CreateDateMonth_10                             27516 non-null  bool
#  46  CreateDateMonth_11                             27516 non-null  bool
#  47  CreateDateMonth_12                             27516 non-null  bool
# dtypes: bool(45), float64(2), int64(1)
# memory usage: 1.8 MB

# %%
df = df.replace({True: 1, False: 0})

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (40,20))
sb.heatmap(df.corr(), annot = True)
plt.show()

# %% [raw]
# plt.figure(figsize=(8,5))
# sb.scatterplot(x= 'Top12CMMCompany_YES',y='Top24CMMCompany_YES',data=df,hue='Top12CMMCompany_YES')
# plt.title('Top 12 CMM Company and Top 24 CMM Company')
# plt.show()

# %% [markdown]
# Since we know there is a correlation between the top 12 and 24 CMM Company variables, we will drop `Top12CMMCompany_YES` from our independent variables

# %%
X = df.drop(['StageName', 'Top12CMMCompany_YES'], axis=1)
y = df['StageName']

# %% [markdown]
# ### Splitting data into testing and training sets
# - 70/30 split

# %%
from sklearn.model_selection import train_test_split #split train and test set
from sklearn.preprocessing import MinMaxScaler #scale features
import numpy as np

# %%
######split data
#split the training and testing sets
 
np.random.seed(0)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=0)

# %%
X_train.shape
# Out:
# (19261, 46)

# %%
X_test.shape
# Out:
# (8255, 46)

# %% [markdown]
# ### Scale the data
# When scaling the data, the scaler function returns an array of the values, so we convert it back to a dataframe after the transformation
# - Purpose: To remove outliers

# %%
# instantiate the scaler
scaler = MinMaxScaler()

# %%
#scale between 0 and 1 returns array
X_train_array = scaler.fit_transform(X_train)
X_train_array
# Out:
# array([[0.77387707, 0.00243334, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.30620421, 0.00253117, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.0668237 , 0.00297875, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.10045938, 0.0023842 , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.2719917 , 0.00237183, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.04350377, 0.00254376, 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
#convert back to df
X_train = pd.DataFrame(X_train_array, columns=X_train.columns, index=X_train.index)
X_train
# Out:
#        CurrentCompanyMarketCap  TotalOpportunityAmount  LegacySFInstance_RHP  \
# 8186                  0.773877                0.002433                   0.0
# 8381                  0.306204                0.002531                   0.0
# 9077                  0.066824                0.002979                   0.0
# 11444                 0.167787                0.002370                   0.0
# 16303                 0.020501                0.002351                   1.0
# ...                        ...                     ...                   ...
# 13123                 0.119323                0.002401                   0.0
# 19648                 0.190290                0.002351                   1.0
# 9845                  0.100459                0.002384                   0.0
# 10799                 0.271992                0.002372                   1.0
# 2732                  0.043504                0.002544                   0.0
#
#        LegacySFInstance_RxC  CurrentCompanyMarketCapCategory_Medium  \
# 8186                    0.0                                     0.0
# 8381                    1.0                                     0.0
# 9077                    1.0                                     0.0
# 11444                   1.0                                     0.0
# 16303                   0.0                                     0.0
# ...                     ...                                     ...
# 13123                   1.0                                     0.0
# 19648                   0.0                                     0.0
# 9845                    1.0                                     0.0
# 10799                   0.0                                     0.0
# 2732                    1.0                                     0.0
#
#        CurrentCompanyMarketCapCategory_Mega  \
# 8186                                    1.0
# 8381                                    1.0
# 9077                                    0.0
# 11444                                   0.0
# 16303                                   0.0
# ...                                     ...
# 13123                                   0.0
# 19648                                   0.0
# 9845                                    0.0
# 10799                                   0.0
# 2732                                    0.0
#
#        CurrentCompanyMarketCapCategory_Micro  \
# 8186                                     0.0
# 8381                                     0.0
# 9077                                     0.0
# 11444                                    0.0
# 16303                                    0.0
# ...                                      ...
# 13123                                    0.0
# 19648                                    0.0
# 9845                                     0.0
# 10799                                    0.0
# 2732                                     0.0
#
#        CurrentCompanyMarketCapCategory_Not Available  \
# 8186                                             0.0
# 8381                                             0.0
# 9077                                             0.0
# 11444                                            0.0
# 16303                                            0.0
# ...                                              ...
# 13123                                            0.0
# 19648                                            0.0
# 9845                                             0.0
# 10799                                            0.0
# 2732                                             0.0
#
#        CurrentCompanyMarketCapCategory_Private  \
# 8186                                       0.0
# 8381                                       0.0
# 9077                                       0.0
# 11444                                      0.0
# 16303                                      0.0
# ...                                        ...
# 13123                                      0.0
# 19648                                      1.0
# 9845                                       0.0
# 10799                                      0.0
# 2732                                       0.0
#
#        CurrentCompanyMarketCapCategory_Small  ...  CreateDateMonth_3  \
# 8186                                     0.0  ...                0.0
# 8381                                     0.0  ...                0.0
# 9077                                     0.0  ...                0.0
# 11444                                    0.0  ...                0.0
# 16303                                    0.0  ...                0.0
# ...                                      ...  ...                ...
# 13123                                    0.0  ...                0.0
# 19648                                    0.0  ...                0.0
# 9845                                     0.0  ...                0.0
# 10799                                    0.0  ...                0.0
# 2732                                     0.0  ...                0.0
#
#        CreateDateMonth_4  CreateDateMonth_5  CreateDateMonth_6  \
# 8186                 0.0                0.0                0.0
# 8381                 0.0                0.0                0.0
# 9077                 0.0                0.0                0.0
# 11444                0.0                0.0                0.0
# 16303                0.0                0.0                0.0
# ...                  ...                ...                ...
# 13123                0.0                0.0                0.0
# 19648                0.0                0.0                0.0
# 9845                 0.0                0.0                0.0
# 10799                0.0                0.0                0.0
# 2732                 0.0                0.0                1.0
#
#        CreateDateMonth_7  CreateDateMonth_8  CreateDateMonth_9  \
# 8186                 0.0                0.0                0.0
# 8381                 0.0                0.0                0.0
# 9077                 0.0                1.0                0.0
# 11444                0.0                0.0                0.0
# 16303                0.0                0.0                0.0
# ...                  ...                ...                ...
# 13123                0.0                0.0                0.0
# 19648                0.0                0.0                0.0
# 9845                 0.0                1.0                0.0
# 10799                0.0                0.0                0.0
# 2732                 0.0                0.0                0.0
#
#        CreateDateMonth_10  CreateDateMonth_11  CreateDateMonth_12
# 8186                  0.0                 0.0                 0.0
# 8381                  0.0                 0.0                 0.0
# 9077                  0.0                 0.0                 0.0
# 11444                 1.0                 0.0                 0.0
# 16303                 1.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 13123                 0.0                 0.0                 0.0
# 19648                 1.0                 0.0                 0.0
# 9845                  0.0                 0.0                 0.0
# 10799                 0.0                 0.0                 0.0
# 2732                  0.0                 0.0                 0.0
#
# [19261 rows x 46 columns]

# %%
#Scale between 0 and 1 returns array
X_test_array = scaler.transform(X_test)
 
X_test_array
# Out:
# array([[0.30620421, 0.00235067, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.02067727, 0.0034311 , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.29360019, 0.00235067, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.01852084, 0.00243882, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.30620421, 0.00255216, 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.05573262, 0.00402739, 1.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
#convert back to df
X_test = pd.DataFrame(X_test_array, columns=X_test.columns, index=X_test.index)
 
X_test
# Out:
#        CurrentCompanyMarketCap  TotalOpportunityAmount  LegacySFInstance_RHP  \
# 25921                 0.306204                0.002351                   0.0
# 9327                  0.020677                0.003431                   0.0
# 7982                  0.293600                0.002351                   0.0
# 1127                  0.000117                0.002363                   0.0
# 9675                  0.028988                0.002392                   0.0
# ...                        ...                     ...                   ...
# 225                   0.031218                0.002789                   1.0
# 20611                 0.190290                0.002435                   0.0
# 10009                 0.018521                0.002439                   0.0
# 25857                 0.306204                0.002552                   0.0
# 24748                 0.055733                0.004027                   1.0
#
#        LegacySFInstance_RxC  CurrentCompanyMarketCapCategory_Medium  \
# 25921                   1.0                                     0.0
# 9327                    0.0                                     0.0
# 7982                    1.0                                     0.0
# 1127                    1.0                                     0.0
# 9675                    1.0                                     0.0
# ...                     ...                                     ...
# 225                     0.0                                     0.0
# 20611                   1.0                                     0.0
# 10009                   1.0                                     0.0
# 25857                   1.0                                     0.0
# 24748                   0.0                                     0.0
#
#        CurrentCompanyMarketCapCategory_Mega  \
# 25921                                   1.0
# 9327                                    0.0
# 7982                                    1.0
# 1127                                    0.0
# 9675                                    0.0
# ...                                     ...
# 225                                     0.0
# 20611                                   0.0
# 10009                                   0.0
# 25857                                   1.0
# 24748                                   0.0
#
#        CurrentCompanyMarketCapCategory_Micro  \
# 25921                                    0.0
# 9327                                     0.0
# 7982                                     0.0
# 1127                                     1.0
# 9675                                     0.0
# ...                                      ...
# 225                                      0.0
# 20611                                    0.0
# 10009                                    0.0
# 25857                                    0.0
# 24748                                    0.0
#
#        CurrentCompanyMarketCapCategory_Not Available  \
# 25921                                            0.0
# 9327                                             0.0
# 7982                                             0.0
# 1127                                             0.0
# 9675                                             0.0
# ...                                              ...
# 225                                              0.0
# 20611                                            0.0
# 10009                                            0.0
# 25857                                            0.0
# 24748                                            0.0
#
#        CurrentCompanyMarketCapCategory_Private  \
# 25921                                      0.0
# 9327                                       0.0
# 7982                                       0.0
# 1127                                       0.0
# 9675                                       0.0
# ...                                        ...
# 225                                        0.0
# 20611                                      1.0
# 10009                                      0.0
# 25857                                      0.0
# 24748                                      0.0
#
#        CurrentCompanyMarketCapCategory_Small  ...  CreateDateMonth_3  \
# 25921                                    0.0  ...                1.0
# 9327                                     0.0  ...                0.0
# 7982                                     0.0  ...                0.0
# 1127                                     0.0  ...                0.0
# 9675                                     0.0  ...                0.0
# ...                                      ...  ...                ...
# 225                                      0.0  ...                0.0
# 20611                                    0.0  ...                0.0
# 10009                                    0.0  ...                0.0
# 25857                                    0.0  ...                0.0
# 24748                                    0.0  ...                0.0
#
#        CreateDateMonth_4  CreateDateMonth_5  CreateDateMonth_6  \
# 25921                0.0                0.0                0.0
# 9327                 0.0                0.0                0.0
# 7982                 0.0                0.0                0.0
# 1127                 1.0                0.0                0.0
# 9675                 0.0                0.0                0.0
# ...                  ...                ...                ...
# 225                  0.0                1.0                0.0
# 20611                0.0                0.0                0.0
# 10009                0.0                0.0                0.0
# 25857                0.0                0.0                0.0
# 24748                0.0                0.0                0.0
#
#        CreateDateMonth_7  CreateDateMonth_8  CreateDateMonth_9  \
# 25921                0.0                0.0                0.0
# 9327                 1.0                0.0                0.0
# 7982                 0.0                0.0                0.0
# 1127                 0.0                0.0                0.0
# 9675                 0.0                0.0                0.0
# ...                  ...                ...                ...
# 225                  0.0                0.0                0.0
# 20611                0.0                0.0                0.0
# 10009                0.0                0.0                0.0
# 25857                0.0                0.0                0.0
# 24748                0.0                0.0                0.0
#
#        CreateDateMonth_10  CreateDateMonth_11  CreateDateMonth_12
# 25921                 0.0                 0.0                 0.0
# 9327                  0.0                 0.0                 0.0
# 7982                  0.0                 1.0                 0.0
# 1127                  0.0                 0.0                 0.0
# 9675                  1.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 225                   0.0                 0.0                 0.0
# 20611                 1.0                 0.0                 0.0
# 10009                 0.0                 0.0                 0.0
# 25857                 0.0                 0.0                 1.0
# 24748                 0.0                 0.0                 0.0
#
# [8255 rows x 46 columns]

# %%
import statsmodels.api as sm #logistic regression with summary

# %% [markdown]
# ### Logistic Regression Modeling
# - Focus on p (probability) values for feature elimination
# - Null Hypothesis: Feature does not affect the `StageName`
# - Alternate Hypothesis: Feature does affect the `StageName`
# - P-value: How likely the data could have occurred under the null hypothesis
# - Any feature that has a p-value less than .05 is statistically significant, and we conclude that the feature does affect the `StageName`

# %%
# Logistic regression model using statsmodels for summary and p values
lm = sm.GLM(y_train,(sm.add_constant(X_train)), family = sm.families.Binomial())
lm.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              StageName   No. Observations:                19261
# Model:                            GLM   Df Residuals:                    19214
# Model Family:                Binomial   Df Model:                           46
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11715.
# Date:                Fri, 23 Feb 2024   Deviance:                       23430.
# Time:                        09:57:48   Pearson chi2:                 1.88e+04
# No. Iterations:                    25   Pseudo R-squ. (CS):             0.1452
# Covariance Type:            nonrobust
# =================================================================================================================
#                                                     coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                           -26.9883   1.81e+04     -0.001      0.999   -3.54e+04    3.54e+04
# CurrentCompanyMarketCap                           0.2429      0.132      1.839      0.066      -0.016       0.502
# TotalOpportunityAmount                           -1.1164      1.290     -0.865      0.387      -3.646       1.413
# LegacySFInstance_RHP                              0.3311      0.053      6.230      0.000       0.227       0.435
# LegacySFInstance_RxC                             -0.0458      0.049     -0.941      0.347      -0.141       0.050
# CurrentCompanyMarketCapCategory_Medium            0.0285      0.063      0.450      0.652      -0.096       0.153
# CurrentCompanyMarketCapCategory_Mega             -0.2034      0.065     -3.128      0.002      -0.331      -0.076
# CurrentCompanyMarketCapCategory_Micro            -0.4572      0.069     -6.612      0.000      -0.593      -0.322
# CurrentCompanyMarketCapCategory_Not Available     0.2317      0.104      2.238      0.025       0.029       0.435
# CurrentCompanyMarketCapCategory_Private          -0.0787      0.053     -1.498      0.134      -0.182       0.024
# CurrentCompanyMarketCapCategory_Small            -0.1734      0.072     -2.415      0.016      -0.314      -0.033
# Top24CMMCompany_YES                               0.0530      0.045      1.171      0.241      -0.036       0.142
# OpportunityType_Renewal                           1.3278      0.042     31.303      0.000       1.245       1.411
# OpportunityType_Termination                       0.7430      0.273      2.722      0.006       0.208       1.278
# ImpactedFY_FY 2005                                0.0630   3.57e+05   1.77e-07      1.000   -6.99e+05    6.99e+05
# ImpactedFY_FY 2007                               53.1637   1.09e+05      0.000      1.000   -2.13e+05    2.13e+05
# ImpactedFY_FY 2008                               28.9442   1.81e+04      0.002      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2009                               27.3439   1.81e+04      0.002      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2010                               26.9907   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2011                               26.7852   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2012                               27.6194   1.81e+04      0.002      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2013                               26.8044   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2014                               26.9103   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2015                               26.7522   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2016                               27.0791   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2017                               26.8868   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2018                               26.9945   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2019                               27.0500   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2020                               27.0784   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2021                               26.7337   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2022                               26.7900   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2023                               26.8118   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2024                               27.2894   1.81e+04      0.002      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2025                               25.2277   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2026                               26.4714   1.81e+04      0.001      0.999   -3.54e+04    3.54e+04
# ImpactedFY_FY 2027                                1.0181   3.57e+05   2.86e-06      1.000   -6.99e+05    6.99e+05
# CreateDateMonth_2                                 0.0750      0.083      0.907      0.365      -0.087       0.237
# CreateDateMonth_3                                -0.0895      0.079     -1.134      0.257      -0.244       0.065
# CreateDateMonth_4                                -0.0406      0.082     -0.498      0.619      -0.200       0.119
# CreateDateMonth_5                                -0.1022      0.083     -1.238      0.216      -0.264       0.060
# CreateDateMonth_6                                -0.2065      0.079     -2.622      0.009      -0.361      -0.052
# CreateDateMonth_7                                -0.1803      0.080     -2.241      0.025      -0.338      -0.023
# CreateDateMonth_8                                -0.0001      0.077     -0.001      0.999      -0.152       0.152
# CreateDateMonth_9                                -0.4488      0.075     -5.966      0.000      -0.596      -0.301
# CreateDateMonth_10                                0.0152      0.080      0.191      0.849      -0.141       0.172
# CreateDateMonth_11                                0.0842      0.082      1.026      0.305      -0.077       0.245
# CreateDateMonth_12                                0.2484      0.090      2.746      0.006       0.071       0.426
# =================================================================================================================
# """

# %% [markdown]
# ### Feature Elimination

# %%
from sklearn.linear_model import LogisticRegression # logistic regression with RFE
from sklearn.feature_selection import RFE #recursive feature elimination

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor #variable selection

# %%
#######model reduction
 
# Use the sklearn logistic regression model for RFE and VIF features
 
##instantiate logistic regression model
lr = LogisticRegression()

# %%
#RFE
#instead of backward/forward stepwise elimination based on p value we will have rfe do it for us targeting 10 results.
 
#instantiate with options
rfe = RFE(estimator=lr, n_features_to_select=10) # target 10 top features with RFE

# %%
#fit rfe
rfe = rfe.fit(X_train, y_train)

# %%
# show RFE support and ranking.
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
#the 10 columns with true for support were chosen by rfe and ranked first most important
# Out:
# [('CurrentCompanyMarketCap', False, 20),
#  ('TotalOpportunityAmount', False, 14),
#  ('LegacySFInstance_RHP', False, 17),
#  ('LegacySFInstance_RxC', False, 33),
#  ('CurrentCompanyMarketCapCategory_Medium', False, 34),
#  ('CurrentCompanyMarketCapCategory_Mega', False, 21),
#  ('CurrentCompanyMarketCapCategory_Micro', False, 15),
#  ('CurrentCompanyMarketCapCategory_Not Available', False, 19),
#  ('CurrentCompanyMarketCapCategory_Private', False, 28),
#  ('CurrentCompanyMarketCapCategory_Small', False, 24),
#  ('Top24CMMCompany_YES', False, 32),
#  ('OpportunityType_Renewal', False, 10),
#  ('OpportunityType_Termination', False, 11),
#  ('ImpactedFY_FY 2005', False, 27),
#  ('ImpactedFY_FY 2007', True, 1),
#  ('ImpactedFY_FY 2008', True, 1),
#  ('ImpactedFY_FY 2009', True, 1),
#  ('ImpactedFY_FY 2010', False, 8),
#  ('ImpactedFY_FY 2011', False, 9),
#  ('ImpactedFY_FY 2012', True, 1),
#  ('ImpactedFY_FY 2013', False, 7),
#  ('ImpactedFY_FY 2014', False, 5),
#  ('ImpactedFY_FY 2015', False, 3),
#  ('ImpactedFY_FY 2016', True, 1),
#  ('ImpactedFY_FY 2017', True, 1),
#  ('ImpactedFY_FY 2018', True, 1),
#  ('ImpactedFY_FY 2019', True, 1),
#  ('ImpactedFY_FY 2020', True, 1),
#  ('ImpactedFY_FY 2021', False, 6),
#  ('ImpactedFY_FY 2022', False, 4),
#  ('ImpactedFY_FY 2023', False, 2),
#  ('ImpactedFY_FY 2024', True, 1),
#  ('ImpactedFY_FY 2025', False, 16),
#  ('ImpactedFY_FY 2026', False, 12),
#  ('ImpactedFY_FY 2027', False, 31),
#  ('CreateDateMonth_2', False, 26),
#  ('CreateDateMonth_3', False, 30),
#  ('CreateDateMonth_4', False, 35),
#  ('CreateDateMonth_5', False, 29),
#  ('CreateDateMonth_6', False, 22),
#  ('CreateDateMonth_7', False, 23),
#  ('CreateDateMonth_8', False, 37),
#  ('CreateDateMonth_9', False, 13),
#  ('CreateDateMonth_10', False, 36),
#  ('CreateDateMonth_11', False, 25),
#  ('CreateDateMonth_12', False, 18)]

# %%
# save supported columns
col = X_train.columns[rfe.support_]

# %%
col
# Out:
# Index(['ImpactedFY_FY 2007', 'ImpactedFY_FY 2008', 'ImpactedFY_FY 2009',
#        'ImpactedFY_FY 2012', 'ImpactedFY_FY 2016', 'ImpactedFY_FY 2017',
#        'ImpactedFY_FY 2018', 'ImpactedFY_FY 2019', 'ImpactedFY_FY 2020',
#        'ImpactedFY_FY 2024'],
#       dtype='object')

# %%
#redefine xtrain as a subset based on the cols selected by rfe
#add the constant back to the set of columns for the model
X_train = sm.add_constant(X_train[col])
 
X_train
# Out:
#        const  ImpactedFY_FY 2007  ImpactedFY_FY 2008  ImpactedFY_FY 2009  \
# 8186     1.0                 0.0                 0.0                 0.0
# 8381     1.0                 0.0                 0.0                 0.0
# 9077     1.0                 0.0                 0.0                 0.0
# 11444    1.0                 0.0                 0.0                 0.0
# 16303    1.0                 0.0                 0.0                 0.0
# ...      ...                 ...                 ...                 ...
# 13123    1.0                 0.0                 0.0                 0.0
# 19648    1.0                 0.0                 0.0                 0.0
# 9845     1.0                 0.0                 0.0                 0.0
# 10799    1.0                 0.0                 0.0                 0.0
# 2732     1.0                 0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2012  ImpactedFY_FY 2016  ImpactedFY_FY 2017  \
# 8186                  0.0                 0.0                 0.0
# 8381                  0.0                 0.0                 0.0
# 9077                  0.0                 0.0                 0.0
# 11444                 0.0                 0.0                 0.0
# 16303                 0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 13123                 0.0                 0.0                 0.0
# 19648                 0.0                 0.0                 0.0
# 9845                  0.0                 0.0                 0.0
# 10799                 0.0                 0.0                 0.0
# 2732                  0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2018  ImpactedFY_FY 2019  ImpactedFY_FY 2020  \
# 8186                  0.0                 0.0                 0.0
# 8381                  0.0                 0.0                 0.0
# 9077                  0.0                 0.0                 0.0
# 11444                 0.0                 0.0                 0.0
# 16303                 0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 13123                 0.0                 0.0                 0.0
# 19648                 0.0                 0.0                 0.0
# 9845                  1.0                 0.0                 0.0
# 10799                 0.0                 0.0                 0.0
# 2732                  0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2024
# 8186                  1.0
# 8381                  0.0
# 9077                  0.0
# 11444                 0.0
# 16303                 0.0
# ...                   ...
# 13123                 0.0
# 19648                 0.0
# 9845                  0.0
# 10799                 0.0
# 2732                  0.0
#
# [19261 rows x 11 columns]

# %%
# build the second model based off the supported columns
lm = sm.GLM(y_train,X_train, family = sm.families.Binomial())
 
lm.fit().summary() #some high pvalues
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              StageName   No. Observations:                19261
# Model:                            GLM   Df Residuals:                    19250
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -13030.
# Date:                Fri, 23 Feb 2024   Deviance:                       26060.
# Time:                        12:35:30   Pearson chi2:                 1.93e+04
# No. Iterations:                    21   Pseudo R-squ. (CS):            0.02009
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0021      0.020     -0.102      0.919      -0.042       0.038
# ImpactedFY_FY 2007    22.5682   1.45e+04      0.002      0.999   -2.85e+04    2.85e+04
# ImpactedFY_FY 2008     1.9092      0.197      9.705      0.000       1.524       2.295
# ImpactedFY_FY 2009     0.3667      0.152      2.418      0.016       0.069       0.664
# ImpactedFY_FY 2012     0.5916      0.091      6.505      0.000       0.413       0.770
# ImpactedFY_FY 2016     0.4194      0.062      6.719      0.000       0.297       0.542
# ImpactedFY_FY 2017     0.2484      0.057      4.339      0.000       0.136       0.361
# ImpactedFY_FY 2018     0.3939      0.058      6.771      0.000       0.280       0.508
# ImpactedFY_FY 2019     0.3969      0.056      7.148      0.000       0.288       0.506
# ImpactedFY_FY 2020     0.3938      0.054      7.344      0.000       0.289       0.499
# ImpactedFY_FY 2024     0.7396      0.060     12.308      0.000       0.622       0.857
# ======================================================================================
# """

# %%
#Remove P Values above threshold (.05)
X_train = X_train.drop(['ImpactedFY_FY 2007'], axis=1)
 
#rebuild the 3rd model with high pvalues removed
lm = sm.GLM(y_train,X_train, family = sm.families.Binomial())

# %%
lm.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              StageName   No. Observations:                19261
# Model:                            GLM   Df Residuals:                    19251
# Model Family:                Binomial   Df Model:                            9
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -13038.
# Date:                Fri, 23 Feb 2024   Deviance:                       26076.
# Time:                        12:36:46   Pearson chi2:                 1.93e+04
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.01931
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0002      0.020      0.010      0.992      -0.040       0.040
# ImpactedFY_FY 2008     1.9069      0.197      9.693      0.000       1.521       2.292
# ImpactedFY_FY 2009     0.3644      0.152      2.402      0.016       0.067       0.662
# ImpactedFY_FY 2012     0.5893      0.091      6.480      0.000       0.411       0.767
# ImpactedFY_FY 2016     0.4171      0.062      6.683      0.000       0.295       0.539
# ImpactedFY_FY 2017     0.2461      0.057      4.299      0.000       0.134       0.358
# ImpactedFY_FY 2018     0.3916      0.058      6.732      0.000       0.278       0.506
# ImpactedFY_FY 2019     0.3946      0.056      7.107      0.000       0.286       0.503
# ImpactedFY_FY 2020     0.3915      0.054      7.302      0.000       0.286       0.497
# ImpactedFY_FY 2024     0.7373      0.060     12.271      0.000       0.620       0.855
# ======================================================================================
# """

# %%
    #VIF
######check VIF for correlation
 
#create a dataframe containing VIFs
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
 
print(vif) # all under 10-15
 
#no issues with correlation
# Out:
#              Features   VIF
# 0               const  2.01
# 7  ImpactedFY_FY 2019  1.07
# 8  ImpactedFY_FY 2020  1.07
# 4  ImpactedFY_FY 2016  1.06
# 5  ImpactedFY_FY 2017  1.06
# 6  ImpactedFY_FY 2018  1.06
# 9  ImpactedFY_FY 2024  1.06
# 3  ImpactedFY_FY 2012  1.03
# 1  ImpactedFY_FY 2008  1.01
# 2  ImpactedFY_FY 2009  1.01

# %%
#create predictions for revenue probability
y_train_predic = lm.fit().predict(X_train)
 
print(y_train_predic)
# Out:
# 8186     0.676450
# 8381     0.500052
# 9077     0.500052
# 11444    0.500052
# 16303    0.500052
#            ...
# 13123    0.500052
# 19648    0.500052
# 9845     0.596717
# 10799    0.500052
# 2732     0.500052
# Length: 19261, dtype: float64

# %%
#compare predicted probability in training set to actual labels in training set
y_train_predic2 = pd.DataFrame({'StageName':y_train.values, 'StageNameProbability':y_train_predic})
y_train_predic2.head()
# Out:
#        StageName  StageNameProbability
# 8186           1              0.676450
# 8381           1              0.500052
# 9077           0              0.500052
# 11444          1              0.500052
# 16303          1              0.500052

# %%
#label probability at 50%
y_train_predic2['Prediction'] = y_train_predic2.StageNameProbability.map(lambda x: 1 if x > 0.5 else 0)
y_train_predic2.head()
# Out:
#        StageName  StageNameProbability  Prediction
# 8186           1              0.676450           1
# 8381           1              0.500052           1
# 9077           0              0.500052           1
# 11444          1              0.500052           1
# 16303          1              0.500052           1

# %%
from sklearn import metrics #model performance
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score #model performance
from sklearn.metrics import confusion_matrix, roc_curve, auc, roc_auc_score #Receiver operating characteristic
### confusion matrix to understand how good the model is 
cmatrix = metrics.confusion_matrix(y_train_predic2.StageName, y_train_predic2.Prediction )
print(cmatrix)
# Out:
# [[    0  8534]
#  [    0 10727]]

# %%
### check cmatrix for train
 
TN = cmatrix[0,0] # true negatives
print("True Negatives", TN)
FP = cmatrix[0,1] # false positives
print("False Positives", FP)
FN = cmatrix[1,0] # false negatives
print("False Negatives", FN)
TP = cmatrix[1,1] # true positive 
print("True Positives", TP)
# Out:
# True Negatives 0
# False Positives 8534
# False Negatives 0
# True Positives 10727

# %%
accuracy = metrics.accuracy_score(y_train_predic2.StageName, y_train_predic2.Prediction)
#(TN+TP) / (TP+TN+FP+FN)
print("Accuracy", accuracy) #56%
 
sensitivity = TP / (TP+FN)
print("Sensitivity", sensitivity) #100%
 
specificity = TN/ (TN+FP)
print("Specificity", specificity) #0%
 
precision = TP / (TP+FP)
print("Precision", precision) #56%
# Out:
# Accuracy 0.5569285083848191
# Sensitivity 1.0
# Specificity 0.0
# Precision 0.5569285083848191

# %%
X_train
# Out:
#        const  ImpactedFY_FY 2008  ImpactedFY_FY 2009  ImpactedFY_FY 2012  \
# 8186     1.0                 0.0                 0.0                 0.0
# 8381     1.0                 0.0                 0.0                 0.0
# 9077     1.0                 0.0                 0.0                 0.0
# 11444    1.0                 0.0                 0.0                 0.0
# 16303    1.0                 0.0                 0.0                 0.0
# ...      ...                 ...                 ...                 ...
# 13123    1.0                 0.0                 0.0                 0.0
# 19648    1.0                 0.0                 0.0                 0.0
# 9845     1.0                 0.0                 0.0                 0.0
# 10799    1.0                 0.0                 0.0                 0.0
# 2732     1.0                 0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2016  ImpactedFY_FY 2017  ImpactedFY_FY 2018  \
# 8186                  0.0                 0.0                 0.0
# 8381                  0.0                 0.0                 0.0
# 9077                  0.0                 0.0                 0.0
# 11444                 0.0                 0.0                 0.0
# 16303                 0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 13123                 0.0                 0.0                 0.0
# 19648                 0.0                 0.0                 0.0
# 9845                  0.0                 0.0                 1.0
# 10799                 0.0                 0.0                 0.0
# 2732                  0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2019  ImpactedFY_FY 2020  ImpactedFY_FY 2024
# 8186                  0.0                 0.0                 1.0
# 8381                  0.0                 0.0                 0.0
# 9077                  0.0                 0.0                 0.0
# 11444                 0.0                 0.0                 0.0
# 16303                 0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 13123                 0.0                 0.0                 0.0
# 19648                 0.0                 0.0                 0.0
# 9845                  0.0                 0.0                 0.0
# 10799                 0.0                 0.0                 0.0
# 2732                  0.0                 0.0                 0.0
#
# [19261 rows x 10 columns]

# %%
######apply model to test
 
#match X_test to X_train shape
cols_to_keep = ['ImpactedFY_FY 2008', 'ImpactedFY_FY 2009', 'ImpactedFY_FY 2012', 'ImpactedFY_FY 2016', 'ImpactedFY_FY 2017', 'ImpactedFY_FY 2018', 'ImpactedFY_FY 2019', 'ImpactedFY_FY 2020', 'ImpactedFY_FY 2024']
X_test = X_test[cols_to_keep]
X_test = sm.add_constant(X_test)

# %%
X_test
# Out:
#        const  ImpactedFY_FY 2008  ImpactedFY_FY 2009  ImpactedFY_FY 2012  \
# 25921    1.0                 0.0                 0.0                 0.0
# 9327     1.0                 0.0                 0.0                 0.0
# 7982     1.0                 0.0                 0.0                 0.0
# 1127     1.0                 0.0                 0.0                 0.0
# 9675     1.0                 0.0                 0.0                 0.0
# ...      ...                 ...                 ...                 ...
# 225      1.0                 0.0                 0.0                 0.0
# 20611    1.0                 0.0                 0.0                 0.0
# 10009    1.0                 0.0                 0.0                 0.0
# 25857    1.0                 0.0                 0.0                 0.0
# 24748    1.0                 0.0                 0.0                 0.0
#
#        ImpactedFY_FY 2016  ImpactedFY_FY 2017  ImpactedFY_FY 2018  \
# 25921                 0.0                 0.0                 0.0
# 9327                  0.0                 0.0                 0.0
# 7982                  0.0                 0.0                 0.0
# 1127                  0.0                 0.0                 0.0
# 9675                  0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 225                   1.0                 0.0                 0.0
# 20611                 1.0                 0.0                 0.0
# 10009                 0.0                 0.0                 0.0
# 25857                 1.0                 0.0                 0.0
# 24748                 1.0                 0.0                 0.0
#
#        ImpactedFY_FY 2019  ImpactedFY_FY 2020  ImpactedFY_FY 2024
# 25921                 0.0                 0.0                 0.0
# 9327                  0.0                 0.0                 0.0
# 7982                  0.0                 0.0                 0.0
# 1127                  0.0                 0.0                 0.0
# 9675                  0.0                 0.0                 0.0
# ...                   ...                 ...                 ...
# 225                   0.0                 0.0                 0.0
# 20611                 0.0                 0.0                 0.0
# 10009                 0.0                 0.0                 0.0
# 25857                 0.0                 0.0                 0.0
# 24748                 0.0                 0.0                 0.0
#
# [8255 rows x 10 columns]

# %%
#use the final model from the training set to predict
y_test_predic = lm.fit().predict(X_test)
 
y_test_predic
# Out:
# 25921    0.500052
# 9327     0.500052
# 7982     0.500052
# 1127     0.500052
# 9675     0.500052
#            ...
# 225      0.602831
# 20611    0.602831
# 10009    0.500052
# 25857    0.602831
# 24748    0.602831
# Length: 8255, dtype: float64

# %%
#compare predicted probability in training set to actual labels in training set
y_test_predic2 = pd.DataFrame({'StageName':y_test.values, 'StageNameProbability':y_test_predic})
y_test_predic2.head()
# Out:
#        StageName  StageNameProbability
# 25921          1              0.500052
# 9327           1              0.500052
# 7982           0              0.500052
# 1127           1              0.500052
# 9675           0              0.500052

# %%
#label probability at 50%
y_test_predic2['Prediction'] = y_test_predic2.StageNameProbability.map(lambda x: 1 if x > 0.5 else 0)
y_test_predic2.head()
# Out:
#        StageName  StageNameProbability  Prediction
# 25921          1              0.500052           1
# 9327           1              0.500052           1
# 7982           0              0.500052           1
# 1127           1              0.500052           1
# 9675           0              0.500052           1

# %%
### confusion matrix to understand how good the model is 
cmatrix2 = metrics.confusion_matrix(y_test_predic2.StageName, y_test_predic2.Prediction )
print(cmatrix2)
# Out:
# [[   0 3601]
#  [   0 4654]]

# %%
TN2 = cmatrix2[0,0] # true negatives
print("True Negatives", TN2)
FP2 = cmatrix2[0,1] # false positives
print("False Positives", FP2)
FN2 = cmatrix2[1,0] # false negatives
print("False Negatives", FN2)
TP2 = cmatrix2[1,1] # true positive 
print("True Positives", TP2)
# Out:
# True Negatives 0
# False Positives 3601
# False Negatives 0
# True Positives 4654

# %%
accuracy = metrics.accuracy_score(y_test_predic2.StageName, y_test_predic2.Prediction)
#(TN+TP) / (TP+TN+FP+FN)
print("Accuracy", accuracy) #88.83% train -> 87.51% test
 
sensitivity = TP2 / (TP2+FN2)
print("Sensitivity", sensitivity) #37.87% train -> 36.50% test
 
specificity = TN2/ (TN2+FP2)
print("Specificity", specificity) #97.75% train -> 97.82% test
 
precision = TP2 / (TP2+FP2)
print("Precision", precision) #74.69 train -> 77.21% test
# Out:
# Accuracy 0.5637795275590551
# Sensitivity 1.0
# Specificity 0.0
# Precision 0.5637795275590551

# %%
######check ROC/AUC
 
#set up train variables
fpr, tpr, thresholds = roc_curve(y_train, y_train_predic)
roc_auc = roc_auc_score(y_train, y_train_predic)

# %%
#set up test variables
fpr2, tpr2, thresholds2 = roc_curve(y_test, y_test_predic)
roc_auc2 = roc_auc_score(y_test, y_test_predic)

# %%
#create figure and subplots for training and test sets
plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label='Training Set (AUC = %0.2f)' % roc_auc)
plt.plot(fpr2, tpr2,label='Test Set (AUC = %0.2f)' % roc_auc2)
plt.plot([0, 1], [0, 1],'r--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic(ROC-AUC)')
plt.legend(loc="lower right")
plt.show()
