# %%
import http.client
import json
from io import StringIO

conn = http.client.HTTPSConnection("zillow-com1.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "8c0485d516msh04a5857c91ea0c2p11d01cjsn9d987a8c0f66",
    'X-RapidAPI-Host': "zillow-com1.p.rapidapi.com"
}

conn.request("GET", "/propertyComps?zpid=34105260", headers=headers)


res = conn.getresponse()
data = res.read()

data_str = data.decode('utf-8')

df = pd.read_csv(StringIO(data_str))

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
import requests

url = "https://zillow-com-api.p.rapidapi.com/search_property"

querystring = {"currentPage":"21","isRecentlySold":"true"}

headers = {
	"X-RapidAPI-Key": "8c0485d516msh04a5857c91ea0c2p11d01cjsn9d987a8c0f66",
	"X-RapidAPI-Host": "zillow-com-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring, verify=False)

print(response.json())
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zillow-com-api.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
json = response.json()
json.keys()
# Out:
# dict_keys(['data'])

# %%
results = json['data']['results']
df = pd.DataFrame.from_dict(results)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 46 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   zpid                         41 non-null     object
#  1   id                           41 non-null     object
#  2   rawHomeStatusCd              41 non-null     object
#  3   marketingStatusSimplifiedCd  41 non-null     object
#  4   imgSrc                       41 non-null     object
#  5   hasImage                     41 non-null     bool
#  6   detailUrl                    41 non-null     object
#  7   statusType                   41 non-null     object
#  8   statusText                   41 non-null     object
#  9   countryCurrency              41 non-null     object
#  10  soldPrice                    41 non-null     object
#  11  unformattedPrice             41 non-null     int64
#  12  address                      41 non-null     object
# ...

# %%
df = pd.DataFrame()
df2 = pd.DataFrame()

# %%
a = []
for x in range(1,3):
    var a + x = 3;
    a.append(a + x)
    
    
print(a)
# Out:
#   Cell In[174], line 3
#     var a + x = 3;
#         ^
# SyntaxError: invalid syntax

# %%
import requests

url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"Columbus, OH","status":"recentlySold", "page": "3"}

headers = {
	"X-RapidAPI-Key": "c575fae906msh3e98aca22d2272bp14dadfjsnacb918d9f18e",
	"X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

finalDF = pd.DataFrame()

a = []

for x in range(1,21):
    querystring = {"location":"Columbus, OH","status":"recentlySold", "page": x}
    response = requests.get(url, headers=headers, params=querystring, verify=False)
    results = json['results']
    a.append(pd.DataFrame.from_dict(results))
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zillow56.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zillow56.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
print(results)
# Out:
# [{'city': 'Columbus', 'country': 'USA', 'currency': 'USD', 'dateSold': 1710486000000, 'daysOnZillow': 1, 'homeStatus': 'RECENTLY_SOLD', 'homeStatusForHDP': 'RECENTLY_SOLD', 'homeType': 'MULTI_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/b176412afc86babc1e7043e809f27ab4-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 39.943768, 'listing_sub_type': {}, 'livingArea': 2444.0, 'longitude': -82.98946, 'lotAreaUnit': 'sqft', 'lotAreaValue': 3920.4, 'price': 520000.0, 'priceForHDP': 520000.0, 'rentZestimate': 3319, 'shouldHighlight': False, 'state': 'OH', 'streetAddress': '276 1/2 Reinhard Ave', 'taxAssessedValue': 348900.0, 'timeOnZillow': 112552000, 'zestimate': 575500, 'zipcode': '43206', 'zpid': 33837334}, {'bathrooms': 1.0, 'bedrooms': 2.0, 'city': 'Columbus', 'country': 'USA', 'currency': 'USD', 'dateSold': 171048600000
# ...

# %%
finalDF = pd.concat(a)

# %%
finalDF.shape
# Out:
# (820, 39)

# %%
print(a[0])
# Out:
#                 city country currency       dateSold  daysOnZillow  \
# 0           Columbus     USA      USD  1710486000000             1
# 1           Columbus     USA      USD  1710486000000             1
# 2           Columbus     USA      USD  1710486000000             1
# 3           Columbus     USA      USD  1710486000000             1
# 4           Columbus     USA      USD  1710486000000             1
# 5           Columbus     USA      USD  1710486000000             1
# 6           Columbus     USA      USD  1710486000000             1
# 7           Columbus     USA      USD  1710486000000             1
# 8           Columbus     USA      USD  1710486000000             1
# 9           Columbus     USA      USD  1710486000000             1
# 10          Columbus     USA      USD  1710486000000             1
# 11          Columbus     USA      USD  1710486000000             1
# 12          Columbus     USA      USD  1710486000000             1
# ...

# %%
finalDF.head()
# Out:
#        city country currency       dateSold  daysOnZillow     homeStatus  \
# 0  Columbus     USA      USD  1710486000000             1  RECENTLY_SOLD
# 1  Columbus     USA      USD  1710486000000             1  RECENTLY_SOLD
# 2  Columbus     USA      USD  1710486000000             1  RECENTLY_SOLD
# 3  Columbus     USA      USD  1710486000000             1  RECENTLY_SOLD
# 4  Columbus     USA      USD  1710486000000             1  RECENTLY_SOLD
#
#   homeStatusForHDP       homeType  \
# 0    RECENTLY_SOLD   MULTI_FAMILY
# 1    RECENTLY_SOLD  SINGLE_FAMILY
# 2    RECENTLY_SOLD  SINGLE_FAMILY
# 3    RECENTLY_SOLD  SINGLE_FAMILY
# 4    RECENTLY_SOLD  SINGLE_FAMILY
#
#                                               imgSrc  isFeatured  ...  \
# 0  https://photos.zillowstatic.com/fp/b176412afc8...       False  ...
# 1  https://photos.zillowstatic.com/fp/9c05a0e0d1e...       False  ...
# 2  https://photos.zillowstatic.com/fp/9669ad766ce...       False  ...
# ...

# %%
finalDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 820 entries, 0 to 40
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city                     820 non-null    object
#  1   country                  820 non-null    object
#  2   currency                 820 non-null    object
#  3   dateSold                 820 non-null    int64
#  4   daysOnZillow             820 non-null    int64
#  5   homeStatus               820 non-null    object
#  6   homeStatusForHDP         820 non-null    object
#  7   homeType                 820 non-null    object
#  8   imgSrc                   820 non-null    object
#  9   isFeatured               820 non-null    bool
#  10  isNonOwnerOccupied       820 non-null    bool
#  11  isPreforeclosureAuction  820 non-null    bool
#  12  isPremierBuilder         820 non-null    bool
#  13  isShowcaseListing        820 non-null    bool
# ...

# %%
import requests
access_token = '6baca547742c6f96a6ff71b138424f21'
url = "https://api.bridgedataoutput.com/api/v2/zestimates_v2/zestimates?access_token=54c00a09dc254aed6564c7a116cdfd99&address='3151 Strathaven Court'"


# "https://api.bridgedataoutput.com/api/v2/datasets?access_token=6baca547742c6f96a6ff71b138424f21"
# https://api.bridgedataoutput.com/api/v2/datasets?access_token=6baca547742c6f96a6ff71b138424f21


response = requests.get(url, verify = False)

print(response.json())
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bridgedataoutput.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'success': False, 'status': 401, 'bundle': {'name': 'AuthorizationError', 'message': 'Unauthorized request'}}

# %%
json.keys()
# Out:
# dict_keys(['success', 'status', 'bundle', 'total'])

# %%
results = json['bundle']
df = pd.DataFrame.from_dict(results)

# %%
df
# Out:
#                                      id datasetCode  \
# 0  5ac285d2-661d-4004-aaba-297f7ec3fb16    triangle
# 1  511e8ab7-52d1-4b35-b0c7-3bd63e6c8884      sccomm
# 2  1043c0a4-863b-4757-b618-00b098a87bdc      united
# 3  c08e57c4-3fb7-474f-9313-af06c819690e     reviews
# 4  76e8e288-fdfd-4779-bf50-db610f1c08a8      roatan
# 5  f2a7e92b-b3ea-4a93-b588-10afb3a2835a        nsar
# 6  a66cdc86-2c96-463f-995e-98e39e649202        rahb
# 7  72356f9b-1079-4fdd-8f86-e69dd9745538      gcmls2
# 8  3b6f99dc-8c46-4f26-bee3-7f2f696109f8       acbor
# 9  b3d8ac41-cf21-4b23-856f-2b696b17ad2a      iresds
#
#                                                 name description
# 0                                       Triangle MLS        None
# 1                      South Carolina Commercial MLS        None
# 2                                         MLS United        None
# 3                               Zillow Agent Reviews        None
# ...

# %%
import requests

#/ Set your API key and listing URL
api_key = "bda8de12-6a61-4f83-83a1-edcaa1e8be7c"  # CHANGE WITH YOUR API KEY
listing_url = "https://www.zillow.com/columbus-oh/sold/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-83.99681025097657%2C%22east%22%3A-82.14973383496094%2C%22south%22%3A39.653022843556556%2C%22north%22%3A40.250973283370826%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A10920%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22rs%22%3A%7B%22value%22%3Atrue%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%7D"
#/ API endpoint and default headers
api_url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

parameters = {"api_key": api_key, "url": listing_url}

#/ Make the API request
response = requests.get(api_url, params=parameters, verify = False)
response_content = response.text

print(response_content)
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'app.scrapeak.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
json = response.json()

# %%
json.keys()
# Out:
# dict_keys(['is_success', 'data', 'message'])

# %%
test = pd.json_normalize(response.json()['data']['cat1']['searchResults']['mapResults'])

# %%
test.shape
# Out:
# (500, 90)

# %%
import requests

#/ Set your API key and listing URL
api_key = "bda8de12-6a61-4f83-83a1-edcaa1e8be7c"  # CHANGE WITH YOUR API KEY
listing_url = "https://www.zillow.com/columbus-oh/sold/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-83.99681025097657%2C%22east%22%3A-82.14973383496094%2C%22south%22%3A39.653022843556556%2C%22north%22%3A40.250973283370826%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A10920%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22rs%22%3A%7B%22value%22%3Atrue%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%7D" #/ API endpoint and default headers
api_url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

parameters = {"api_key": api_key, "url": listing_url, "page": 3}

#/ Make the API request
response = requests.get(api_url, params=parameters, verify = False)
response_content = response.text

print(response_content)
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'app.scrapeak.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
json = response.json()

# %%
test2 = pd.json_normalize(response.json()['data']['cat1']['searchResults']['mapResults'])

# %%
test2.shape
# Out:
# (500, 90)

# %%
test3 = pd.concat([test, test2])

# %%
test3.shape
# Out:
# (1000, 90)

# %%
df = pd.DataFrame(test3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 499
# Data columns (total 90 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   zpid                                                 974 non-null    object
#  1   rawHomeStatusCd                                      974 non-null    object
#  2   marketingStatusSimplifiedCd                          974 non-null    object
#  3   imgSrc                                               1000 non-null   object
#  4   hasImage                                             896 non-null    object
#  5   detailUrl                                            1000 non-null   object
#  6   statusType                                           1000 non-null   object
#  7   statusText                                           1000 non-null   object
# ...

# %%
import requests

url = "https://zillow-working-api.p.rapidapi.com/search/byurl"

querystring = {"url":"https://www.zillow.com/columbus-oh-43220/sold/?searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A40.06579227862069%2C%22south%22%3A40.02847200179606%2C%22east%22%3A-83.0161766609497%2C%22west%22%3A-83.13161893695067%7D%2C%22mapZoom%22%3A15%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22rs%22%3A%7B%22value%22%3Atrue%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A76588%2C%22regionType%22%3A7%7D%5D%7D","page":"1"}

headers = {
	"X-RapidAPI-Key": "c575fae906msh3e98aca22d2272bp14dadfjsnacb918d9f18e",
	"X-RapidAPI-Host": "zillow-working-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring, verify = False)

a = response.json()
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zillow-working-api.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
a.keys()
# Out:
# dict_keys(['message', 'total_results', 'resultsPerPage', 'totalPages', 'currentPage', 'listResultsTitle', 'Results', 'paginated_url'])

# %%
df1 = pd.json_normalize(response.json()['Results'])

# %%
df1.head()
# Out:
#        zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0  33997640      ComingSoon                 Coming Soon
# 1  33910058      ComingSoon                 Coming Soon
# 2  33925486         ForSale           For Sale by Agent
# 3  33937759         ForSale           For Sale by Agent
# 4  33925031         ForSale           For Sale by Agent
#
#                                               imgSrc hasImage  \
# 0  https://photos.zillowstatic.com/fp/97752d471cf...     True
# 1  https://maps.googleapis.com/maps/api/staticmap...      NaN
# 2  https://photos.zillowstatic.com/fp/686884616dd...     True
# 3  https://photos.zillowstatic.com/fp/6d9ac15e149...     True
# 4  https://photos.zillowstatic.com/fp/ae422e79c57...     True
#
#                                            detailUrl statusType  \
# 0  https://www.zillow.com/homedetails/2247-Lytham...   FOR_SALE
# 1  https://www.zillow.com/homedetails/3544-Shattu...   FOR_SALE
# ...

# %%
df.to_csv('test.csv')

# %%
df.shape
# Out:
# (1000, 90)

# %%
import requests

url = "https://zillow-working-api.p.rapidapi.com/search/byurl"

querystring = {"url":"https://www.zillow.com/columbus-oh-43201/sold/?searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A40.06579227862069%2C%22south%22%3A40.02847200179606%2C%22east%22%3A-83.0161766609497%2C%22west%22%3A-83.13161893695067%7D%2C%22mapZoom%22%3A15%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22rs%22%3A%7B%22value%22%3Atrue%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A76588%2C%22regionType%22%3A7%7D%5D%7D","page":"1"}

headers = {
	"X-RapidAPI-Key": "c575fae906msh3e98aca22d2272bp14dadfjsnacb918d9f18e",
	"X-RapidAPI-Host": "zillow-working-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring, verify = False)

a = response.json()
# Out:
# C:\Users\EHIDRPC\AppData\Local\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1056: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zillow-working-api.p.rapidapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df2 = pd.json_normalize(response.json()['Results'])

# %%
df2.shape
# Out:
# (41, 94)

# %%
# coding: utf-8
# Web scraping Zillow
# import request module
import requests
from bs4 import BeautifulSoup
header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
'referer':'https://www.zillow.com/homes/for_rent/Manhattan,-New-York,-NY_rb/?searchQueryState=%7B%22pagination'
}
# Enter Zillow URL for the city of your preference
url = 'https://www.zillow.com/homes/for_rent/Manhattan,-New-York,-NY_rb'
html = requests.get(url=url,headers=header)
html.status_code
bsobj = BeautifulSoup(html.content,'html.parser') #bsobj - Beautiful Soup Object
bsobj
# price list is a list variable that will contain
# the price information.
price_list = []
# loop through the price section of the data and extract
# the text and store it in the list.
for price in bsobj.findAll('div',{'class':'list-card-heading'}):
    print('price is: ',price.text.replace( 'bd','b|' ).replace(
    '|s','|' ).replace('io','io|').strip().split('|')[:-1])
    price_list.append(price.text.replace('bd','b|').replace('|s','|').replace('o','o|').strip().split('|')[:-1])
    print(price_list)
# address list is a list variable that will
# contain the address information.
address = []
# loop through the address section of the data
# and extract the text and store it in the list.
for adr in bsobj.findAll('div',{'class':'list-card-info'}):
    address.append(adr.a.text.strip())
    print(address)
    
import pandas as pd
# create a pandas data-frame to store the address
# and price information.
df = pd.DataFrame( price_list,columns = ['Price1','Price2','Price3','Price4'] )
df['Address'] = address
print(df)
# Out:
# Empty DataFrame
# Columns: [Price1, Price2, Price3, Price4, Address]
# Index: []
